# %%
#Flipkart data scraping using BeautifulSoup and Requests libraries in Python.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (26.1.2)Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (4.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\sande\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

Products = []
Prices = []
Descriptions = []
Reviews = []

headers = {"User-Agent": "Mozilla/5.0"}
for i in range(1, 10):
    url = f"https://www.flipkart.com/search?q=5g+mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&page={i}"

    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")

    box = soup.find("div", class_="QSCKDh dLgFEE")

    names = box.find_all("div", class_="RG5Slk")
    for i in names:
        name = i.text
        Products.append(name)
    print("Products: ",Products)

    price = box.find_all("div", class_="hZ3P6w DeU9vF")
    for i in price:
        pri = i.text
        Prices.append(pri)
    print("Prices: ",Prices)

    Discription = box.find_all("div", class_="CMXw7N")
    for i in Discription:
        dis = i.text
        Descriptions.append(dis)
    print("Descriptions:",Descriptions)

    Review = box.find_all("div", class_="MKiFS6")
    for i in Review:
        rev = i.text
        Reviews.append(rev)
    print("Reviews: ",len(Reviews))
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[5], line 15
#      12 url = f"https://www.flipkart.com/search?q=5g+mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&page={i}"
#      14 r = requests.get(url, headers=headers)
# ---> 15 soup = BeautifulSoup(r.text, "lxml")
#      17 box = soup.find("div", class_="QSCKDh dLgFEE")
#      19 names = box.find_all("div", class_="RG5Slk")
#
# File c:\Users\sande\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:366, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     364     possible_builder_class = builder_registry.lookup(*features)
#     365     if possible_builder_class is None:
# --> 366         raise FeatureNotFound(
#     367             "Couldn't find a tree builder with the features you "
#     368             "requested: %s. Do you need to install a parser library?"
#     369             % ",".join(features)
#     370         )
#     371     builder_class = possible_builder_class
#     373 # At this point either we have a TreeBuilder instance in
#     374 # builder, or we have a builder_class that we can instantiate
#     375 # with the remaining **kwargs.
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0"
}

for i in range(1, 10):

    url = f"https://www.flipkart.com/search?q=5g+mobile+under+50000&page={i}"

    print("Scraping page: ", i)
    
    print(url)

    r = requests.get(url, headers=headers)

    soup = BeautifulSoup(r.text, "html.parser")
# Out:
# Scraping page:  1
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=1
# Scraping page:  2
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=2
# Scraping page:  3
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=3
# Scraping page:  4
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=4
# Scraping page:  5
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=5
# Scraping page:  6
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=6
# Scraping page:  7
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=7
# Scraping page:  8
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=8
# Scraping page:  9
# https://www.flipkart.com/search?q=5g+mobile+under+50000&page=9

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

Products = []
Prices = []
Descriptions = []
Reviews = []

headers = {"User-Agent": "Mozilla/5.0"}
for i in range(1, 10):
    url = f"https://www.flipkart.com/search?q=5g+mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&page={i}"

    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")

    box = soup.find("div", class_="QSCKDh dLgFEE")

    names = box.find_all("div", class_="RG5Slk")
    for i in names:
        name = i.text
        Products.append(name)
    #print("Products: ",Products)

    price = box.find_all("div", class_="hZ3P6w DeU9vF")
    for i in price:
        pri = i.text
        Prices.append(pri)
    #print("Prices: ",Prices)

    Discription = box.find_all("div", class_="CMXw7N")
    for i in Discription:
        dis = i.text
        Descriptions.append(dis)
    #print(Descriptions)

    Review = box.find_all("div", class_="MKiFS6")
    for i in Review:
        rev = i.text
        Reviews.append(rev)
    #print("Reviews: ",len(Reviews))
# Out:
#                                          Products Name   Prices  \
# 0                    IQOO 15R 5G (Dark Knight, 256 GB)  ₹49,510
# 1                 OnePlus Nord 6 (Pitch Black, 256 GB)  ₹49,735
# 2                       Google Pixel 10a (Fog, 256 GB)  ₹49,999
# 3             OPPO Reno15c 5G (Afterglow Pink, 256 GB)  ₹44,999
# 4               OPPO Reno15 5G (Twilight Blue, 256 GB)  ₹47,999
# ..                                                 ...      ...
# 211                  OPPO K14 5G (Prism White, 128 GB)  ₹21,999
# 212                  OPPO K14 5G (Prism White, 256 GB)  ₹21,999
# 213                     OPPO K14 5G (Icy Blue, 256 GB)  ₹31,999
# 214                  OPPO K14 5G (Prism White, 256 GB)      NaN
# 215  MOTOROLA Edge 70 Fusion (Pantone COUNTRY AIR, ...      NaN
#
#                                           Descriptions Reviews
# 0    8 GB RAM | 256 GB ROM16.74 cm (6.59 inch) Disp...     4.6
# 1    12 GB RAM | 256 GB ROM | Expandable Upto 256 G...     4.6
# 2    8 GB RAM | 256 GB ROM16.0 cm (6.3 inch) Full H...     4.5
# 3    12 GB RAM | 256 GB ROM16.69 cm (6.57 inch) Ful...     4.3
# 4    8 GB RAM | 256 GB ROM16.74 cm (6.59 inch) Full...     4.5
# ..                                                 ...     ...
# 211  6 GB RAM | 128 GB ROM17.14 cm (6.75 inch) HD+ ...     NaN
# 212  8 GB RAM | 256 GB ROM17.14 cm (6.75 inch) HD+ ...     NaN
# 213  6 GB RAM | 256 GB ROM17.14 cm (6.75 inch) HD+ ...     NaN
# 214  6 GB RAM | 256 GB ROM17.14 cm (6.75 inch) HD+ ...     NaN
# 215  8 GB RAM | 256 GB ROM17.27 cm (6.8 inch) Super...     NaN
#
# [216 rows x 4 columns]
